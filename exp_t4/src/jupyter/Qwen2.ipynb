# %%
model_name = "Qwen/Qwen-72B-Chat"
cache_dir = "/home/s2210436/.cache"
# cache_dir = ".cache"
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers.generation import GenerationConfig
import torch

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-72B-Chat", cache_dir=cache_dir, trust_remote_code=True)
# device_map="auto", 
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-72B-Chat", cache_dir=cache_dir, device_map="balanced", 
                                             torch_dtype=torch.float16, trust_remote_code=True, load_in_4bit=True).eval()
# Out:
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 9
#       6 import torch
#       8 # Note: The default behavior now has injection attack prevention off.
# ----> 9 tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-72B-Chat", cache_dir=cache_dir, trust_remote_code=True)
#      10 # device_map="auto",
#      11 model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-72B-Chat", cache_dir=cache_dir, device_map="balanced",
#      12                                              torch_dtype=torch.float16, trust_remote_code=True, load_in_4bit=True).eval()
#
# ...

# %%
# !pip install "transformers>=4.32.0" accelerate tiktoken einops scipy transformers_stream_generator==0.0.4 peft deepspeed
# !pip install auto-gptq optimum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.1 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [8 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/JOBs/tmpdir/pbs.8479192.spcc-adm1/pip-install-7kjfkcdk/deepspeed_f3f5ac97e90e4872963075e6efa86714/setup.py", line 100, in <module>
#           cuda_major_ver, cuda_minor_ver = installed_cuda_version()
#         File "/JOBs/tmpdir/pbs.8479192.spcc-adm1/pip-install-7kjfkcdk/deepspeed_f3f5ac97e90e4872963075e6efa86714/op_builder/builder.py", line 50, in installed_cuda_version
# ...
